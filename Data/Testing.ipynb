# %%
import pandas as pd
df = pd.read_csv('Melbourne_housing_FULL.csv')

# %%
df.query('Rooms < Bedroom2')
# Out:
#                 Suburb          Address  Rooms Type      Price Method  \
# 8           Abbotsford     53 Turner St      2    h        NaN      S
# 9           Abbotsford     99 Turner St      2    h        NaN      S
# 11          Abbotsford     124 Yarra St      3    h  1876000.0      S
# 13          Abbotsford    17 Raphael St      4    h        NaN      W
# 18          Abbotsford    10 Valiant St      2    h  1097000.0      S
# ...                ...              ...    ...  ...        ...    ...
# 31124         Carnegie     2/5 Anzac St      2    u   780000.0      S
# 32235   West Footscray   342 Geelong Rd      3    h   910000.0     PI
# 32335    Glen Waverley      4 Canova Dr      3    h  1075000.0      S
# 32768  North Melbourne     136 Capel St      3    h  1400000.0     VB
# 34451          Malvern  1177 Malvern Rd      3    h  2025000.0     VB
#
#             SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...
