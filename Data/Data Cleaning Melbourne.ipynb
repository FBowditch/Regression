# %%
import pandas as pd
df = pd.read_csv('Melbourne_housing_FULL.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.loc[df.Date >= ('2018')]

# %%
df
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 29217    Abbotsford  1009/1 Acacia Pl      2    u   750000.0     VB
# 29218    Aberfeldie      22 Beaver St      4    h  1630000.0     PI
# 29219  Airport West    32 Coniston Av      3    h   970000.0      S
# 29220  Airport West    23 Matthews Av      4    h   790000.0     VB
# 29221  Airport West       8 Miriam Ct      3    h  1025000.0      S
# ...             ...               ...    ...  ...        ...    ...
# 34852    Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853    Yarraville     29A Murray St      2    h   888000.0     SP
# 34854    Yarraville    147A Severn St      2    t   705000.0      S
# 34855    Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856    Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG       Date  Distance  Postcode  ...  Bathroom  Car  \
# 29217         Jellis 2018-06-01       3.0    3067.0  ...       NaN  NaN
# ...

# %%
df.drop(['Method', 'SellerG','Postcode','CouncilArea','Lattitude','Longtitude','Regionname','Propertycount','BuildingArea','YearBuilt'], axis=1, inplace = True)

# %%
df
# Out:
#              Suburb           Address  Rooms Type      Price       Date  \
# 29217    Abbotsford  1009/1 Acacia Pl      2    u   750000.0 2018-06-01
# 29218    Aberfeldie      22 Beaver St      4    h  1630000.0 2018-06-01
# 29219  Airport West    32 Coniston Av      3    h   970000.0 2018-06-01
# 29220  Airport West    23 Matthews Av      4    h   790000.0 2018-06-01
# 29221  Airport West       8 Miriam Ct      3    h  1025000.0 2018-06-01
# ...             ...               ...    ...  ...        ...        ...
# 34852    Yarraville       13 Burns St      4    h  1480000.0 2018-02-24
# 34853    Yarraville     29A Murray St      2    h   888000.0 2018-02-24
# 34854    Yarraville    147A Severn St      2    t   705000.0 2018-02-24
# 34855    Yarraville  12/37 Stephen St      3    h  1140000.0 2018-02-24
# 34856    Yarraville  3 Tarrengower St      2    h  1020000.0 2018-02-24
#
#        Distance  Bedroom2  Bathroom  Car  Landsize
# 29217       3.0       NaN       NaN  NaN       NaN
# ...

# %%
df.isna().sum()
# Out:
# Suburb         0
# Address        0
# Rooms          0
# Type           0
# Price       1039
# Date           0
# Distance       1
# Bedroom2    1400
# Bathroom    1403
# Car         1566
# Landsize    1744
# dtype: int64

# %%
df.dropna(subset=['Distance','Bedroom2','Bathroom','Car','Landsize','Price'], inplace = True)

# %%
df.head()
# Out:
#              Suburb         Address  Rooms Type      Price       Date  \
# 29219  Airport West  32 Coniston Av      3    h   970000.0 2018-06-01
# 29220  Airport West  23 Matthews Av      4    h   790000.0 2018-06-01
# 29221  Airport West     8 Miriam Ct      3    h  1025000.0 2018-06-01
# 29227        Altona    175 Blyth St      4    u  1160000.0 2018-06-01
# 29228        Altona   17 Merritt Ct      3    h   925000.0 2018-06-01
#
#        Distance  Bedroom2  Bathroom  Car  Landsize
# 29219      10.4       3.0       1.0  2.0     634.0
# 29220      10.4       4.0       2.0  1.0     585.0
# 29221      10.4       3.0       1.0  1.0     791.0
# 29227      11.0       4.0       3.0  3.0     689.0
# 29228      11.0       3.0       1.0  4.0     836.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2186 entries, 29219 to 34856
# Data columns (total 11 columns):
# Suburb      2186 non-null object
# Address     2186 non-null object
# Rooms       2186 non-null int64
# Type        2186 non-null object
# Price       2186 non-null float64
# Date        2186 non-null datetime64[ns]
# Distance    2186 non-null float64
# Bedroom2    2186 non-null float64
# Bathroom    2186 non-null float64
# Car         2186 non-null float64
# Landsize    2186 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 204.9+ KB

# %%
df.groupby('Type').describe()
# Out:
#        Rooms                                                Price  \
#        count      mean       std  min  25%  50%  75%  max   count
# Type
# h     2044.0  3.425147  0.770716  1.0  3.0  3.0  4.0  7.0  2044.0
# t      125.0  3.032000  0.646779  1.0  3.0  3.0  3.0  4.0   125.0
# u       17.0  2.529412  0.624264  2.0  2.0  2.0  3.0  4.0    17.0
#
#                     ...  Car       Landsize                                  \
#               mean  ...  75%   max    count        mean          std    min
# Type                ...
# h     1.166221e+06  ...  2.0  11.0   2044.0  642.894325  1349.126149   66.0
# t     9.836160e+05  ...  2.0   4.0    125.0  307.768000   276.330218   71.0
# u     6.848824e+05  ...  2.0   6.0     17.0  456.470588   340.472487  105.0
#
#
#         25%    50%    75%      max
# Type
# h     441.0  590.0  690.0  42800.0
# t     188.0  256.0  334.0   2399.0
# u     233.0  334.0  689.0   1439.0
#
# [3 rows x 56 columns]

# %%
# df['Type'] = df['Type'].map({'h': 'House', 't': 'Townhouse','u':'Apartment'}) 

# #Changing Names of Properties (RUN ONCE)

# %%
df.isna().sum()
# Out:
# Suburb      0
# Address     0
# Rooms       0
# Type        0
# Price       0
# Date        0
# Distance    0
# Bedroom2    0
# Bathroom    0
# Car         0
# Landsize    0
# dtype: int64

# %%
df.rename(columns={'Date': 'Date_Sold', 'Bedroom2':'Bedrooms','Bathroom':'Bathrooms','Car':'Parking_Spaces','Distance':'Distance_to_Melbourne_CBD','Landsize':'Size'}, inplace=True)

# %%
df.query('Rooms == Bedrooms')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# ~/opt/anaconda3/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# ~/opt/anaconda3/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'Rooms'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.drop(['Rooms'], axis=1, inplace = True)

# %%
df['Suburb'].unique()
# Out:
# array(['Airport West', 'Altona', 'Altona Meadows', 'Altona North',
#        'Ardeer', 'Ashwood', 'Aspendale', 'Avondale Heights', 'Balwyn',
#        'Balwyn North', 'Bayswater', 'Bentleigh', 'Bentleigh East',
#        'Berwick', 'Blackburn North', 'Blackburn South', 'Boronia',
#        'Braybrook', 'Briar Hill', 'Brighton', 'Brighton East',
#        'Brunswick', 'Brunswick West', 'Bulleen', 'Bundoora', 'Cairnlea',
#        'Camberwell', 'Carlton', 'Carlton North', 'Carnegie',
#        'Caulfield South', 'Chadstone', 'Cheltenham', 'Clarinda',
#        'Clifton Hill', 'Coburg', 'Coburg North', 'Collingwood',
#        'Craigieburn', 'Cremorne', 'Deepdene', 'Diamond Creek',
#        'Dingley Village', 'Doncaster', 'Doncaster East', 'Doreen',
#        'Endeavour Hills', 'Epping', 'Essendon', 'Fairfield', 'Fawkner',
#        'Ferntree Gully', 'Fitzroy', 'Frankston', 'Frankston South',
#        'Gisborne', 'Gladstone Park', 'Glen Iris', 'Glenroy', 'Gowanbrae',
# ...

# %%
df.sort_values(by='Date_Sold', ascending = True)
# Out:
#                 Suburb           Address       Type      Price  Date_Sold  \
# 31389     Airport West        78 King St      House  1025000.0 2018-01-20
# 31391  Dandenong North       4 Crouch Ct      House   631000.0 2018-01-20
# 31395          Kilsyth  22 Colchester Rd      House   650000.0 2018-01-20
# 31396        Knoxfield     6 Honeypot Cl      House   935000.0 2018-01-20
# 31402          Rosanna    3 Pickworth Ct      House  1180000.0 2018-01-20
# ...                ...               ...        ...        ...        ...
# 32310      Craigieburn   13 Creighton Wy      House   613500.0 2018-10-03
# 32311      Craigieburn      34 Emblem Wy      House   740000.0 2018-10-03
# 32312      Craigieburn        3 Epsom Ct      House   650000.0 2018-10-03
# 32292          Bulleen        42 Apex Cr      House  1158000.0 2018-10-03
# 32306     Coburg North      2 Gaffney St  Townhouse   850000.0 2018-10-03
#
#        Distance_to_Melbourne_CBD  Bedrooms  Bathrooms  Parking_Spaces   Size
# ...

# %%
df = df.loc[df.Distance_to_Melbourne_CBD <= (25)]

# %%
df['Distance_to_Melbourne_CBD'].describe()
# Out:
# count    2186.000000
# mean       14.163815
# std         7.829248
# min         1.600000
# 25%         8.200000
# 50%        13.400000
# 75%        18.000000
# max        48.100000
# Name: Distance_to_Melbourne_CBD, dtype: float64

# %%
typehome = pd.DataFrame(df['Type'])

# %%
typehome = pd.get_dummies(typehome, drop_first = True)

# %%
df = df.drop(['Type'], axis = 1)

# %%
df = pd.concat([typehome, df], axis = 1)

# %%
df
# Out:
#        Type_House  Type_Townhouse        Suburb           Address      Price  \
# 29219           1               0  Airport West    32 Coniston Av   970000.0
# 29220           1               0  Airport West    23 Matthews Av   790000.0
# 29221           1               0  Airport West       8 Miriam Ct  1025000.0
# 29227           0               0        Altona      175 Blyth St  1160000.0
# 29228           1               0        Altona     17 Merritt Ct   925000.0
# ...           ...             ...           ...               ...        ...
# 34849           1               0       Wollert   35 Kingscote Wy   570000.0
# 34852           1               0    Yarraville       13 Burns St  1480000.0
# 34853           1               0    Yarraville     29A Murray St   888000.0
# 34854           0               1    Yarraville    147A Severn St   705000.0
# 34856           1               0    Yarraville  3 Tarrengower St  1020000.0
#
# ...

# %%
df.sort_values(by = ['Distance_to_Melbourne_CBD'])
# Out:
#        Type_House  Type_Townhouse           Suburb           Address  \
# 32524           0               0          Carlton      226 Elgin St
# 29353           1               0          Carlton   173 Drummond St
# 32523           1               0          Carlton    164 Canning St
# 33168           0               1          Carlton        26 Tyne St
# 33598           1               0  North Melbourne       9 George St
# ...           ...             ...              ...               ...
# 33356           1               0         Gisborne  47 Willowbank Rd
# 31763           1               0         Gisborne       47 Goode St
# 32384           1               0         Pakenham    1 Smethurst Av
# 32083           1               0   Riddells Creek  5 Sutherlands Rd
# 29755           1               0     New Gisborne     14 Carbine Ct
#
#            Price  Date_Sold  Distance_to_Melbourne_CBD  Bedrooms  Bathrooms  \
# ...
